# %% [markdown]
# <a href="https://colab.research.google.com/github/classical16/gomycode/blob/main/API_to_Pandas_Dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# What You're Aiming For
#
# In this checkpoint, we are going to practice consuming public APIs through the NASA public APIs portal.
#
# Portal description : The objective of this portal is to make NASA data, including imagery, eminently accessible to application developers and data professionals. Before starting to use its APIs endpoints, it's mandatory that you generate your API KEY and store it somewhere for later use. The API key acts as the user identifier when requesting the API. To get your KEY, fill in the provided form with your personal information, and then we shall receive an email containing your personal API KEY.
#
# ➡️ NASA API PORTAL
#
# https://i.imgur.com/hisTmpk.png
#
#
#
#
# Instructions
#
# Go to the NASA API portal and generate your API KEY
# Import the requests package and store your API KEY in variable
# Go back to portal website and click on 'browse APIs'
# Click on the first dropdown menu, named 'APOD' and read its documentation
# Follow the provided documentation to ask the API endpoint for the astronomy picture of the day. Get then display the image on your notebook.
# Go through the list of the provided API endpoints once again and select 'Astronomy Picture of the Day' option. Store the results in a pandas dataframe
# Do the necessary data pre-processing tasks on the previous result in order to get a clean dataframe with the following columns :
# Asteroid ID
# Asteroid name
# The Minimal estimated diameter in Kilometre
# Absolute_magnitude
# Relative_velocity(km/s)
# Try to export the new dataframe into a CSV file and share it with your colleagues

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.2.2)

# %%
import requests
import json
import webbrowser

# %%
NASA_API_KEY = 'eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'

# %%
#Api url
url = 'https://api.nasa.gov/planetary/apod'

# %%
parameters = {
    'api_key': NASA_API_KEY,
    'date': '2024-03-04'
}

# %%
# Make a GET request to the APOD API
response = requests.get(url, params=parameters)

# %%
json_data = json.loads(response.text)
print(json_data)
# Out:
# {'copyright': '\nN. D. Liao\n', 'date': '2024-03-04', 'explanation': "What's happening across that field?  Pictured here are not auroras but nearby light pillars, a phenomenon typically much closer.   In most places on Earth, a lucky viewer can see a Sun pillar, a column of light appearing to extend up from the Sun caused by flat fluttering ice-crystals reflecting sunlight from the upper atmosphere.  Usually, these ice crystals evaporate before reaching the ground.  During freezing temperatures, however, flat fluttering ice crystals may form near the ground in a form of light snow  sometimes known as a crystal fog.  These ice crystals may then reflect ground lights in columns not unlike a Sun pillar.  The featured image was taken last month across the Wulan Butong Grasslands in Inner Mongolia, China.", 'hdurl': 'https://apod.nasa.gov/apod/image/2403/PillarsMongolia_Liao_6240.jpg', 'media_type': 'image', 'service_version': 'v1', 'title': 'Light Pillars Over Inner Mongolia', 'url': 'https://apod.nasa.gov/apod/image/2403/PillarsMongolia_Liao_960.jpg'}

# %%
image_url = json_data['hdurl']

# %%
# !wget $image_url
# Out:
# --2024-03-04 14:50:53--  https://apod.nasa.gov/apod/image/2403/PillarsMongolia_Liao_6240.jpg
# Resolving apod.nasa.gov (apod.nasa.gov)... 129.164.179.22, 2001:4d0:2310:150::22
# Connecting to apod.nasa.gov (apod.nasa.gov)|129.164.179.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6772115 (6.5M) [image/jpeg]
# Saving to: ‘PillarsMongolia_Liao_6240.jpg.4’
#
# PillarsMongolia_Lia 100%[===================>]   6.46M  4.10MB/s    in 1.6s
#
# 2024-03-04 14:50:55 (4.10 MB/s) - ‘PillarsMongolia_Liao_6240.jpg.4’ saved [6772115/6772115]

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('/content/PillarsMongolia_Liao_6240.jpg') #Replace "image.jpg" with the path of your image
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'Title': [json_data['title']],
    'Date': [json_data['date']],
    'Explanation': [json_data['explanation']],
    'URL': [json_data['url']],
    'HD URL': [json_data['hdurl']]
})

# %%
print(df)
# Out:
#                  Title        Date  \
# 0  Pillars of Creation  2023-08-01
#
#                                   Explanation  \
# 0  These are the famous "Pillars of Creation"
#
#                                                  URL  \
# 0  https://apod.nasa.gov/apod/image/2308/PillarsM...
#
#                                               HD URL
# 0  https://apod.nasa.gov/apod/image/2308/PillarsM...

# %%
url2= "https://api.nasa.gov/neo/rest/v1/feed"

# %%
parameters2 = {
    'api_key': NASA_API_KEY,
    'start_date': '2024-02-04'
}

# %%
# Make a GET request to the APOD API
response2 = requests.get(url2, params=parameters2)

# %% [markdown]
# Do the necessary data pre-processing tasks on the previous result in order to get a clean dataframe with the following columns :
# Asteroid ID
# Asteroid name
# The Minimal estimated diameter in Kilometre
# Absolute_magnitude
# Relative_velocity(km/s)

# %%
json_data2 = json.loads(response2.text)
json_data2
# Out:
# {'links': {'next': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-02-11&end_date=2024-02-18&detailed=false&api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP',
#   'previous': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-01-28&end_date=2024-02-04&detailed=false&api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP',
#   'self': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-02-04&end_date=2024-02-11&detailed=false&api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#  'element_count': 140,
#  'near_earth_objects': {'2024-02-05': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2347813?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '2347813',
#     'neo_reference_id': '2347813',
#     'name': '347813 (2002 NP1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2347813',
#     'absolute_magnitude_h': 17.66,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.7808272775,
#       'estimated_diameter_max': 1.7459828712},
#      'meters': {'estimated_diameter_min': 780.8272774914,
#       'estimated_diameter_max': 1745.9828711568},
#      'miles': {'estimated_diameter_min': 0.4851834262,
#       'estimated_diameter_max': 1.0849031226},
#      'feet': {'estimated_diameter_min': 2561.7693650848,
#       'estimated_diameter_max': 5728.2904430061}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-05',
#       'close_approach_date_full': '2024-Feb-05 03:32',
#       'epoch_date_close_approach': 1707103920000,
#       'relative_velocity': {'kilometers_per_second': '13.310416415',
#        'kilometers_per_hour': '47917.4990939856',
#        'miles_per_hour': '29774.0704787046'},
#       'miss_distance': {'astronomical': '0.2542580463',
#        'lunar': '98.9063800107',
#        'kilometers': '38036462.156841381',
#        'miles': '23634761.6258018178'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2444627?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '2444627',
#     'neo_reference_id': '2444627',
#     'name': '444627 (2006 WU)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2444627',
#     'absolute_magnitude_h': 19.05,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.4116754573,
#       'estimated_diameter_max': 0.9205343072},
#      'meters': {'estimated_diameter_min': 411.6754573069,
#       'estimated_diameter_max': 920.5343072066},
#      'miles': {'estimated_diameter_min': 0.2558031906,
#       'estimated_diameter_max': 0.571993323},
#      'feet': {'estimated_diameter_min': 1350.6413073509,
#       'estimated_diameter_max': 3020.1257764558}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-05',
#       'close_approach_date_full': '2024-Feb-05 22:54',
#       'epoch_date_close_approach': 1707173640000,
#       'relative_velocity': {'kilometers_per_second': '1.9982604604',
#        'kilometers_per_hour': '7193.7376574495',
#        'miles_per_hour': '4469.9088238746'},
#       'miss_distance': {'astronomical': '0.4192329873',
#        'lunar': '163.0816320597',
#        'kilometers': '62716361.933817051',
#        'miles': '38970140.2362592638'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2451370?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '2451370',
#     'neo_reference_id': '2451370',
#     'name': '451370 (2011 AK5)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2451370',
#     'absolute_magnitude_h': 21.48,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1344481952,
#       'estimated_diameter_max': 0.3006353038},
#      'meters': {'estimated_diameter_min': 134.4481951604,
#       'estimated_diameter_max': 300.6353038309},
#      'miles': {'estimated_diameter_min': 0.0835422095,
#       'estimated_diameter_max': 0.1868060594},
#      'feet': {'estimated_diameter_min': 441.1030166101,
#       'estimated_diameter_max': 986.3363302205}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-02-05',
#       'close_approach_date_full': '2024-Feb-05 02:23',
#       'epoch_date_close_approach': 1707099780000,
#       'relative_velocity': {'kilometers_per_second': '8.2382303218',
#        'kilometers_per_hour': '29657.6291584367',
#        'miles_per_hour': '18428.0974068075'},
#       'miss_distance': {'astronomical': '0.4318477396',
#        'lunar': '167.9887707044',
#        'kilometers': '64603502.008474652',
#        'miles': '40142754.7037961176'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3440771?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '3440771',
#     'neo_reference_id': '3440771',
#     'name': '(2008 WZ94)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3440771',
#     'absolute_magnitude_h': 20.26,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.235806068,
#       'estimated_diameter_max': 0.5272783976},
#      'meters': {'estimated_diameter_min': 235.8060679997,
#       'estimated_diameter_max': 527.2783975542},
#      'miles': {'estimated_diameter_min': 0.1465230523,
#       'estimated_diameter_max': 0.3276355052},
#      'feet': {'estimated_diameter_min': 773.6419801361,
#       'estimated_diameter_max': 1729.9160578319}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-02-05',
#       'close_approach_date_full': '2024-Feb-05 11:04',
#       'epoch_date_close_approach': 1707131040000,
#       'relative_velocity': {'kilometers_per_second': '16.1492348048',
#        'kilometers_per_hour': '58137.2452971068',
#        'miles_per_hour': '36124.2233347495'},
#       'miss_distance': {'astronomical': '0.4852630626',
#        'lunar': '188.7673313514',
#        'kilometers': '72594320.554636662',
#        'miles': '45108019.1060114556'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3557844?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '3557844',
#     'neo_reference_id': '3557844',
#     'name': '(2011 DW)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3557844',
#     'absolute_magnitude_h': 22.7,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0766575574,
#       'estimated_diameter_max': 0.1714115092},
#      'meters': {'estimated_diameter_min': 76.6575573531,
#       'estimated_diameter_max': 171.4115092306},
#      'miles': {'estimated_diameter_min': 0.0476327831,
#       'estimated_diameter_max': 0.1065101409},
#      'feet': {'estimated_diameter_min': 251.5011804664,
#       'estimated_diameter_max': 562.3737359442}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-05',
#       'close_approach_date_full': '2024-Feb-05 03:16',
#       'epoch_date_close_approach': 1707102960000,
#       'relative_velocity': {'kilometers_per_second': '14.872591907',
#        'kilometers_per_hour': '53541.3308653544',
#        'miles_per_hour': '33268.5008368643'},
#       'miss_distance': {'astronomical': '0.3844147306',
#        'lunar': '149.5373302034',
#        'kilometers': '57507624.894383822',
#        'miles': '35733581.1211958636'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3616697?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '3616697',
#     'neo_reference_id': '3616697',
#     'name': '(2012 VN6)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3616697',
#     'absolute_magnitude_h': 21.36,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1420872067,
#       'estimated_diameter_max': 0.317716653},
#      'meters': {'estimated_diameter_min': 142.0872067277,
#       'estimated_diameter_max': 317.7166529762},
#      'miles': {'estimated_diameter_min': 0.0882888697,
#       'estimated_diameter_max': 0.1974199144},
#      'feet': {'estimated_diameter_min': 466.1653913206,
#       'estimated_diameter_max': 1042.3775037506}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-05',
#       'close_approach_date_full': '2024-Feb-05 21:27',
#       'epoch_date_close_approach': 1707168420000,
#       'relative_velocity': {'kilometers_per_second': '19.5250537238',
#        'kilometers_per_hour': '70290.1934055846',
#        'miles_per_hour': '43675.5926747089'},
#       'miss_distance': {'astronomical': '0.3671035055',
#        'lunar': '142.8032636395',
#        'kilometers': '54917902.492333285',
#        'miles': '34124402.239177933'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3719865?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '3719865',
#     'neo_reference_id': '3719865',
#     'name': '(2015 KQ57)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3719865',
#     'absolute_magnitude_h': 22.17,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0978486812,
#       'estimated_diameter_max': 0.2187963027},
#      'meters': {'estimated_diameter_min': 97.8486811942,
#       'estimated_diameter_max': 218.7963026589},
#      'miles': {'estimated_diameter_min': 0.0608003329,
#       'estimated_diameter_max': 0.1359536774},
#      'feet': {'estimated_diameter_min': 321.0258672091,
#       'estimated_diameter_max': 717.8356616154}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-05',
#       'close_approach_date_full': '2024-Feb-05 16:45',
#       'epoch_date_close_approach': 1707151500000,
#       'relative_velocity': {'kilometers_per_second': '13.7739572245',
#        'kilometers_per_hour': '49586.2460083548',
#        'miles_per_hour': '30810.9649155802'},
#       'miss_distance': {'astronomical': '0.0716046582',
#        'lunar': '27.8542120398',
#        'kilometers': '10711904.348798034',
#        'miles': '6656068.7163355092'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3776069?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '3776069',
#     'neo_reference_id': '3776069',
#     'name': '(2017 MZ3)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3776069',
#     'absolute_magnitude_h': 22.43,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0868070458,
#       'estimated_diameter_max': 0.1941064553},
#      'meters': {'estimated_diameter_min': 86.8070457914,
#       'estimated_diameter_max': 194.1064553155},
#      'miles': {'estimated_diameter_min': 0.0539393809,
#       'estimated_diameter_max': 0.1206121222},
#      'feet': {'estimated_diameter_min': 284.8000281143,
#       'estimated_diameter_max': 636.8322228574}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-05',
#       'close_approach_date_full': '2024-Feb-05 03:06',
#       'epoch_date_close_approach': 1707102360000,
#       'relative_velocity': {'kilometers_per_second': '25.3080501382',
#        'kilometers_per_hour': '91108.980497664',
#        'miles_per_hour': '56611.5773542291'},
#       'miss_distance': {'astronomical': '0.3684085996',
#        'lunar': '143.3109452444',
#        'kilometers': '55113141.789842852',
#        'miles': '34245718.3131492776'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3802006?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '3802006',
#     'neo_reference_id': '3802006',
#     'name': '(2018 FB2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3802006',
#     'absolute_magnitude_h': 25.6,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0201629919,
#       'estimated_diameter_max': 0.0450858206},
#      'meters': {'estimated_diameter_min': 20.1629919443,
#       'estimated_diameter_max': 45.0858206172},
#      'miles': {'estimated_diameter_min': 0.0125286985,
#       'estimated_diameter_max': 0.0280150214},
#      'feet': {'estimated_diameter_min': 66.1515504905,
#       'estimated_diameter_max': 147.9193637137}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-05',
#       'close_approach_date_full': '2024-Feb-05 07:27',
#       'epoch_date_close_approach': 1707118020000,
#       'relative_velocity': {'kilometers_per_second': '5.5296784427',
#        'kilometers_per_hour': '19906.842393732',
#        'miles_per_hour': '12369.3377084831'},
#       'miss_distance': {'astronomical': '0.2897177554',
#        'lunar': '112.7002068506',
#        'kilometers': '43341159.109020998',
#        'miles': '26930947.4657178524'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54341595?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '54341595',
#     'neo_reference_id': '54341595',
#     'name': '(2023 CE3)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54341595',
#     'absolute_magnitude_h': 25.2,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0242412481,
#       'estimated_diameter_max': 0.0542050786},
#      'meters': {'estimated_diameter_min': 24.2412481101,
#       'estimated_diameter_max': 54.2050786336},
#      'miles': {'estimated_diameter_min': 0.0150628086,
#       'estimated_diameter_max': 0.0336814639},
#      'feet': {'estimated_diameter_min': 79.5316564495,
#       'estimated_diameter_max': 177.8381901842}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-05',
#       'close_approach_date_full': '2024-Feb-05 17:00',
#       'epoch_date_close_approach': 1707152400000,
#       'relative_velocity': {'kilometers_per_second': '15.2642183636',
#        'kilometers_per_hour': '54951.1861089226',
#        'miles_per_hour': '34144.5300575136'},
#       'miss_distance': {'astronomical': '0.0853475503',
#        'lunar': '33.2001970667',
#        'kilometers': '12767811.734597861',
#        'miles': '7933550.3282620418'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54377840?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '54377840',
#     'neo_reference_id': '54377840',
#     'name': '(2023 QN2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54377840',
#     'absolute_magnitude_h': 24.62,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0316632126,
#       'estimated_diameter_max': 0.0708010957},
#      'meters': {'estimated_diameter_min': 31.6632125734,
#       'estimated_diameter_max': 70.8010957001},
#      'miles': {'estimated_diameter_min': 0.0196746021,
#       'estimated_diameter_max': 0.0439937476},
#      'feet': {'estimated_diameter_min': 103.8819343392,
#       'estimated_diameter_max': 232.2870668166}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-05',
#       'close_approach_date_full': '2024-Feb-05 01:44',
#       'epoch_date_close_approach': 1707097440000,
#       'relative_velocity': {'kilometers_per_second': '13.7193327839',
#        'kilometers_per_hour': '49389.5980218733',
#        'miles_per_hour': '30688.7755042023'},
#       'miss_distance': {'astronomical': '0.3516341466',
#        'lunar': '136.7856830274',
#        'kilometers': '52603719.350627742',
#        'miles': '32686435.5143251596'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54392655?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '54392655',
#     'neo_reference_id': '54392655',
#     'name': '(2023 TZ6)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54392655',
#     'absolute_magnitude_h': 26.43,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0137579896,
#       'estimated_diameter_max': 0.0307638},
#      'meters': {'estimated_diameter_min': 13.7579895932,
#       'estimated_diameter_max': 30.7637999642},
#      'miles': {'estimated_diameter_min': 0.0085488158,
#       'estimated_diameter_max': 0.0191157331},
#      'feet': {'estimated_diameter_min': 45.1377625771,
#       'estimated_diameter_max': 100.9311054747}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-05',
#       'close_approach_date_full': '2024-Feb-05 06:07',
#       'epoch_date_close_approach': 1707113220000,
#       'relative_velocity': {'kilometers_per_second': '4.6265154609',
#        'kilometers_per_hour': '16655.455659207',
#        'miles_per_hour': '10349.0524344667'},
#       'miss_distance': {'astronomical': '0.4756383349',
#        'lunar': '185.0233122761',
#        'kilometers': '71154481.791386663',
#        'miles': '44213344.7851274294'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54419609?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '54419609',
#     'neo_reference_id': '54419609',
#     'name': '(2024 AJ2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54419609',
#     'absolute_magnitude_h': 21.12,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1586919792,
#       'estimated_diameter_max': 0.3548460529},
#      'meters': {'estimated_diameter_min': 158.691979174,
#       'estimated_diameter_max': 354.846052917},
#      'miles': {'estimated_diameter_min': 0.0986065938,
#       'estimated_diameter_max': 0.2204910467},
#      'feet': {'estimated_diameter_min': 520.6429929532,
#       'estimated_diameter_max': 1164.1931242522}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-05',
#       'close_approach_date_full': '2024-Feb-05 22:01',
#       'epoch_date_close_approach': 1707170460000,
#       'relative_velocity': {'kilometers_per_second': '23.2274071715',
#        'kilometers_per_hour': '83618.6658175271',
#        'miles_per_hour': '51957.3871020073'},
#       'miss_distance': {'astronomical': '0.1909418604',
#        'lunar': '74.2763836956',
#        'kilometers': '28564495.609677348',
#        'miles': '17749154.5326214824'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54423045?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '54423045',
#     'neo_reference_id': '54423045',
#     'name': '(2024 BL3)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54423045',
#     'absolute_magnitude_h': 24.48,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0337718597,
#       'estimated_diameter_max': 0.0755161741},
#      'meters': {'estimated_diameter_min': 33.7718597164,
#       'estimated_diameter_max': 75.5161740526},
#      'miles': {'estimated_diameter_min': 0.0209848542,
#       'estimated_diameter_max': 0.0469235606},
#      'feet': {'estimated_diameter_min': 110.8000682321,
#       'estimated_diameter_max': 247.7564844786}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-05',
#       'close_approach_date_full': '2024-Feb-05 04:23',
#       'epoch_date_close_approach': 1707106980000,
#       'relative_velocity': {'kilometers_per_second': '15.5068172938',
#        'kilometers_per_hour': '55824.542257743',
#        'miles_per_hour': '34687.1996045404'},
#       'miss_distance': {'astronomical': '0.0508064417',
#        'lunar': '19.7637058213',
#        'kilometers': '7600535.460599179',
#        'miles': '4722753.7382155102'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54423051?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '54423051',
#     'neo_reference_id': '54423051',
#     'name': '(2024 BS3)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54423051',
#     'absolute_magnitude_h': 24.35,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0358554334,
#       'estimated_diameter_max': 0.0801751865},
#      'meters': {'estimated_diameter_min': 35.8554334193,
#       'estimated_diameter_max': 80.1751864882},
#      'miles': {'estimated_diameter_min': 0.0222795265,
#       'estimated_diameter_max': 0.0498185358},
#      'feet': {'estimated_diameter_min': 117.6359401793,
#       'estimated_diameter_max': 263.0419588381}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-05',
#       'close_approach_date_full': '2024-Feb-05 15:07',
#       'epoch_date_close_approach': 1707145620000,
#       'relative_velocity': {'kilometers_per_second': '17.8529211728',
#        'kilometers_per_hour': '64270.5162219486',
#        'miles_per_hour': '39935.1993713547'},
#       'miss_distance': {'astronomical': '0.1456310099',
#        'lunar': '56.6504628511',
#        'kilometers': '21786088.886988913',
#        'miles': '13537247.9038484794'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54423313?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '54423313',
#     'neo_reference_id': '54423313',
#     'name': '(2024 BS4)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54423313',
#     'absolute_magnitude_h': 25.89,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0176422908,
#       'estimated_diameter_max': 0.0394493615},
#      'meters': {'estimated_diameter_min': 17.6422908113,
#       'estimated_diameter_max': 39.4493615328},
#      'miles': {'estimated_diameter_min': 0.0109624079,
#       'estimated_diameter_max': 0.0245126892},
#      'feet': {'estimated_diameter_min': 57.8815333853,
#       'estimated_diameter_max': 129.4270432914}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-05',
#       'close_approach_date_full': '2024-Feb-05 08:35',
#       'epoch_date_close_approach': 1707122100000,
#       'relative_velocity': {'kilometers_per_second': '9.4573672168',
#        'kilometers_per_hour': '34046.5219805997',
#        'miles_per_hour': '21155.1847273343'},
#       'miss_distance': {'astronomical': '0.0277228445',
#        'lunar': '10.7841865105',
#        'kilometers': '4147278.487541215',
#        'miles': '2576999.355110167'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54423322?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '54423322',
#     'neo_reference_id': '54423322',
#     'name': '(2024 BE5)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54423322',
#     'absolute_magnitude_h': 25.52,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0209196771,
#       'estimated_diameter_max': 0.04677782},
#      'meters': {'estimated_diameter_min': 20.9196770901,
#       'estimated_diameter_max': 46.7778200408},
#      'miles': {'estimated_diameter_min': 0.0129988807,
#       'estimated_diameter_max': 0.0290663808},
#      'feet': {'estimated_diameter_min': 68.6341133843,
#       'estimated_diameter_max': 153.4705431027}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-05',
#       'close_approach_date_full': '2024-Feb-05 11:17',
#       'epoch_date_close_approach': 1707131820000,
#       'relative_velocity': {'kilometers_per_second': '9.6038531778',
#        'kilometers_per_hour': '34573.8714401645',
#        'miles_per_hour': '21482.8591734733'},
#       'miss_distance': {'astronomical': '0.0444933645',
#        'lunar': '17.3079187905',
#        'kilometers': '6656112.558333615',
#        'miles': '4135916.558749287'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54423784?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '54423784',
#     'neo_reference_id': '54423784',
#     'name': '(2024 CH)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54423784',
#     'absolute_magnitude_h': 25.94,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0172407032,
#       'estimated_diameter_max': 0.0385513844},
#      'meters': {'estimated_diameter_min': 17.2407032437,
#       'estimated_diameter_max': 38.5513844328},
#      'miles': {'estimated_diameter_min': 0.010712873,
#       'estimated_diameter_max': 0.0239547123},
#      'feet': {'estimated_diameter_min': 56.5639888301,
#       'estimated_diameter_max': 126.4809241026}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-05',
#       'close_approach_date_full': '2024-Feb-05 14:52',
#       'epoch_date_close_approach': 1707144720000,
#       'relative_velocity': {'kilometers_per_second': '20.7971227826',
#        'kilometers_per_hour': '74869.6420173938',
#        'miles_per_hour': '46521.083952419'},
#       'miss_distance': {'astronomical': '0.0058977997',
#        'lunar': '2.2942440833',
#        'kilometers': '882298.272806639',
#        'miles': '548234.7247400582'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54426076?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '54426076',
#     'neo_reference_id': '54426076',
#     'name': '(2024 CN2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54426076',
#     'absolute_magnitude_h': 25.93,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0173202827,
#       'estimated_diameter_max': 0.0387293295},
#      'meters': {'estimated_diameter_min': 17.3202827141,
#       'estimated_diameter_max': 38.7293295383},
#      'miles': {'estimated_diameter_min': 0.0107623214,
#       'estimated_diameter_max': 0.0240652822},
#      'feet': {'estimated_diameter_min': 56.8250763398,
#       'estimated_diameter_max': 127.0647335225}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-05',
#       'close_approach_date_full': '2024-Feb-05 10:06',
#       'epoch_date_close_approach': 1707127560000,
#       'relative_velocity': {'kilometers_per_second': '17.5002946641',
#        'kilometers_per_hour': '63001.0607906866',
#        'miles_per_hour': '39146.4091340797'},
#       'miss_distance': {'astronomical': '0.0308658978',
#        'lunar': '12.0068342442',
#        'kilometers': '4617472.566517686',
#        'miles': '2869164.4079126268'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54426079?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '54426079',
#     'neo_reference_id': '54426079',
#     'name': '(2024 CR2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54426079',
#     'absolute_magnitude_h': 23.88,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0445199816,
#       'estimated_diameter_max': 0.0995497053},
#      'meters': {'estimated_diameter_min': 44.5199816448,
#       'estimated_diameter_max': 99.5497053148},
#      'miles': {'estimated_diameter_min': 0.0276634255,
#       'estimated_diameter_max': 0.0618572999},
#      'feet': {'estimated_diameter_min': 146.0629365795,
#       'estimated_diameter_max': 326.6066551849}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-05',
#       'close_approach_date_full': '2024-Feb-05 12:47',
#       'epoch_date_close_approach': 1707137220000,
#       'relative_velocity': {'kilometers_per_second': '11.2207344268',
#        'kilometers_per_hour': '40394.6439364264',
#        'miles_per_hour': '25099.6608392756'},
#       'miss_distance': {'astronomical': '0.0316409438',
#        'lunar': '12.3083271382',
#        'kilometers': '4733417.797269706',
#        'miles': '2941209.4335297028'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54427296?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '54427296',
#     'neo_reference_id': '54427296',
#     'name': '(2024 CT8)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54427296',
#     'absolute_magnitude_h': 26.54,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0130784109,
#       'estimated_diameter_max': 0.0292442157},
#      'meters': {'estimated_diameter_min': 13.0784108584,
#       'estimated_diameter_max': 29.2442157171},
#      'miles': {'estimated_diameter_min': 0.0081265452,
#       'estimated_diameter_max': 0.0181715076},
#      'feet': {'estimated_diameter_min': 42.9081734807,
#       'estimated_diameter_max': 95.9455926932}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-05',
#       'close_approach_date_full': '2024-Feb-05 08:08',
#       'epoch_date_close_approach': 1707120480000,
#       'relative_velocity': {'kilometers_per_second': '7.553373489',
#        'kilometers_per_hour': '27192.1445605425',
#        'miles_per_hour': '16896.1411576327'},
#       'miss_distance': {'astronomical': '0.0137345572',
#        'lunar': '5.3427427508',
#        'kilometers': '2054660.502513164',
#        'miles': '1276706.8345791032'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54427465?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '54427465',
#     'neo_reference_id': '54427465',
#     'name': '(2024 DM)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54427465',
#     'absolute_magnitude_h': 24.98,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0268259417,
#       'estimated_diameter_max': 0.0599846292},
#      'meters': {'estimated_diameter_min': 26.8259417119,
#       'estimated_diameter_max': 59.9846292283},
#      'miles': {'estimated_diameter_min': 0.0166688622,
#       'estimated_diameter_max': 0.037272709},
#      'feet': {'estimated_diameter_min': 88.0116226061,
#       'estimated_diameter_max': 196.7999709574}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-05',
#       'close_approach_date_full': '2024-Feb-05 12:54',
#       'epoch_date_close_approach': 1707137640000,
#       'relative_velocity': {'kilometers_per_second': '13.365152469',
#        'kilometers_per_hour': '48114.5488884929',
#        'miles_per_hour': '29896.5095579638'},
#       'miss_distance': {'astronomical': '0.0429297223',
#        'lunar': '16.6996619747',
#        'kilometers': '6422195.015771501',
#        'miles': '3990566.9377526738'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54427939?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '54427939',
#     'neo_reference_id': '54427939',
#     'name': '(2024 DT)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54427939',
#     'absolute_magnitude_h': 24.36,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0356906927,
#       'estimated_diameter_max': 0.079806815},
#      'meters': {'estimated_diameter_min': 35.690692667,
#       'estimated_diameter_max': 79.8068149676},
#      'miles': {'estimated_diameter_min': 0.0221771614,
#       'estimated_diameter_max': 0.0495896404},
#      'feet': {'estimated_diameter_min': 117.0954521297,
#       'estimated_diameter_max': 261.8333908182}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-05',
#       'close_approach_date_full': '2024-Feb-05 21:49',
#       'epoch_date_close_approach': 1707169740000,
#       'relative_velocity': {'kilometers_per_second': '16.7223711391',
#        'kilometers_per_hour': '60200.5361008842',
#        'miles_per_hour': '37406.27200113'},
#       'miss_distance': {'astronomical': '0.0382685889',
#        'lunar': '14.8864810821',
#        'kilometers': '5724899.387345643',
#        'miles': '3557287.5256821534'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2024-02-04': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3383667?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '3383667',
#     'neo_reference_id': '3383667',
#     'name': '(2007 RF1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3383667',
#     'absolute_magnitude_h': 26.1,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0160160338,
#       'estimated_diameter_max': 0.0358129403},
#      'meters': {'estimated_diameter_min': 16.0160337979,
#       'estimated_diameter_max': 35.8129403019},
#      'miles': {'estimated_diameter_min': 0.0099518989,
#       'estimated_diameter_max': 0.0222531225},
#      'feet': {'estimated_diameter_min': 52.5460443254,
#       'estimated_diameter_max': 117.4965270602}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-04',
#       'close_approach_date_full': '2024-Feb-04 20:22',
#       'epoch_date_close_approach': 1707078120000,
#       'relative_velocity': {'kilometers_per_second': '10.9204815314',
#        'kilometers_per_hour': '39313.7335131008',
#        'miles_per_hour': '24428.0251376265'},
#       'miss_distance': {'astronomical': '0.3395533151',
#        'lunar': '132.0862395739',
#        'kilometers': '50796452.690398837',
#        'miles': '31563452.0850924706'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3444295?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '3444295',
#     'neo_reference_id': '3444295',
#     'name': '(2009 BB)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3444295',
#     'absolute_magnitude_h': 18.24,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.5977987142,
#       'estimated_diameter_max': 1.3367185619},
#      'meters': {'estimated_diameter_min': 597.7987142312,
#       'estimated_diameter_max': 1336.7185618828},
#      'miles': {'estimated_diameter_min': 0.3714547849,
#       'estimated_diameter_max': 0.8305981495},
#      'feet': {'estimated_diameter_min': 1961.2819335981,
#       'estimated_diameter_max': 4385.5597265676}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-04',
#       'close_approach_date_full': '2024-Feb-04 05:49',
#       'epoch_date_close_approach': 1707025740000,
#       'relative_velocity': {'kilometers_per_second': '17.4922006081',
#        'kilometers_per_hour': '62971.9221893148',
#        'miles_per_hour': '39128.3035403551'},
#       'miss_distance': {'astronomical': '0.4665182872',
#        'lunar': '181.4756137208',
#        'kilometers': '69790142.081168264',
#        'miles': '43365583.4004154832'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3568303?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '3568303',
#     'neo_reference_id': '3568303',
#     'name': '(2011 MD)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3568303',
#     'absolute_magnitude_h': 28.0,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0066765941,
#       'estimated_diameter_max': 0.0149293183},
#      'meters': {'estimated_diameter_min': 6.676594135,
#       'estimated_diameter_max': 14.9293183439},
#      'miles': {'estimated_diameter_min': 0.004148642,
#       'estimated_diameter_max': 0.0092766455},
#      'feet': {'estimated_diameter_min': 21.9048371017,
#       'estimated_diameter_max': 48.9807047955}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-04',
#       'close_approach_date_full': '2024-Feb-04 14:14',
#       'epoch_date_close_approach': 1707056040000,
#       'relative_velocity': {'kilometers_per_second': '2.3261952648',
#        'kilometers_per_hour': '8374.3029531047',
#        'miles_per_hour': '5203.4661877222'},
#       'miss_distance': {'astronomical': '0.1062790146',
#        'lunar': '41.3425366794',
#        'kilometers': '15899114.209858902',
#        'miles': '9879251.4630287676'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3708366?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '3708366',
#     'neo_reference_id': '3708366',
#     'name': '(2015 BS509)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3708366',
#     'absolute_magnitude_h': 20.29,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2325706875,
#       'estimated_diameter_max': 0.5200438667},
#      'meters': {'estimated_diameter_min': 232.5706874555,
#       'estimated_diameter_max': 520.0438667242},
#      'miles': {'estimated_diameter_min': 0.1445126806,
#       'estimated_diameter_max': 0.3231401775},
#      'feet': {'estimated_diameter_min': 763.0272142313,
#       'estimated_diameter_max': 1706.1807197036}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-04',
#       'close_approach_date_full': '2024-Feb-04 08:37',
#       'epoch_date_close_approach': 1707035820000,
#       'relative_velocity': {'kilometers_per_second': '22.4037337451',
#        'kilometers_per_hour': '80653.4414825112',
#        'miles_per_hour': '50114.9120145081'},
#       'miss_distance': {'astronomical': '0.4430831701',
#        'lunar': '172.3593531689',
#        'kilometers': '66284298.479807687',
#        'miles': '41187153.2016806006'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3752782?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '3752782',
#     'neo_reference_id': '3752782',
#     'name': '(2016 JA6)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3752782',
#     'absolute_magnitude_h': 26.3,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0146067964,
#       'estimated_diameter_max': 0.0326617897},
#      'meters': {'estimated_diameter_min': 14.6067964271,
#       'estimated_diameter_max': 32.6617897446},
#      'miles': {'estimated_diameter_min': 0.0090762397,
#       'estimated_diameter_max': 0.020295089},
#      'feet': {'estimated_diameter_min': 47.92256199,
#       'estimated_diameter_max': 107.1581062656}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-04',
#       'close_approach_date_full': '2024-Feb-04 01:02',
#       'epoch_date_close_approach': 1707008520000,
#       'relative_velocity': {'kilometers_per_second': '7.6998185786',
#        'kilometers_per_hour': '27719.3468830255',
#        'miles_per_hour': '17223.7241785111'},
#       'miss_distance': {'astronomical': '0.3152811954',
#        'lunar': '122.6443850106',
#        'kilometers': '47165395.282893798',
#        'miles': '29307217.6350504924'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3780705?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '3780705',
#     'neo_reference_id': '3780705',
#     'name': '(2017 PY26)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3780705',
#     'absolute_magnitude_h': 22.46,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0856160085,
#       'estimated_diameter_max': 0.1914432149},
#      'meters': {'estimated_diameter_min': 85.6160084723,
#       'estimated_diameter_max': 191.4432149063},
#      'miles': {'estimated_diameter_min': 0.0531993048,
#       'estimated_diameter_max': 0.1189572619},
#      'feet': {'estimated_diameter_min': 280.8924252363,
#       'estimated_diameter_max': 628.0945571932}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-04',
#       'close_approach_date_full': '2024-Feb-04 07:21',
#       'epoch_date_close_approach': 1707031260000,
#       'relative_velocity': {'kilometers_per_second': '16.0378475601',
#        'kilometers_per_hour': '57736.2512163283',
#        'miles_per_hour': '35875.061207168'},
#       'miss_distance': {'astronomical': '0.1491488125',
#        'lunar': '58.0188880625',
#        'kilometers': '22312344.663029375',
#        'miles': '13864248.079880375'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3838137?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '3838137',
#     'neo_reference_id': '3838137',
#     'name': '(2019 CB2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3838137',
#     'absolute_magnitude_h': 26.0,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0167708462,
#       'estimated_diameter_max': 0.0375007522},
#      'meters': {'estimated_diameter_min': 16.7708462163,
#       'estimated_diameter_max': 37.5007521798},
#      'miles': {'estimated_diameter_min': 0.0104209175,
#       'estimated_diameter_max': 0.0233018799},
#      'feet': {'estimated_diameter_min': 55.0224631002,
#       'estimated_diameter_max': 123.0339677816}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-04',
#       'close_approach_date_full': '2024-Feb-04 02:13',
#       'epoch_date_close_approach': 1707012780000,
#       'relative_velocity': {'kilometers_per_second': '16.9862666794',
#        'kilometers_per_hour': '61150.5600457486',
#        'miles_per_hour': '37996.579935093'},
#       'miss_distance': {'astronomical': '0.1397726485',
#        'lunar': '54.3715602665',
#        'kilometers': '20909690.499858695',
#        'miles': '12992679.198072191'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3838259?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '3838259',
#     'neo_reference_id': '3838259',
#     'name': '(2019 CC5)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3838259',
#     'absolute_magnitude_h': 21.97,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1072889455,
#       'estimated_diameter_max': 0.2399053753},
#      'meters': {'estimated_diameter_min': 107.2889454508,
#       'estimated_diameter_max': 239.9053752622},
#      'miles': {'estimated_diameter_min': 0.0666662393,
#       'estimated_diameter_max': 0.1490702429},
#      'feet': {'estimated_diameter_min': 351.9978637928,
#       'estimated_diameter_max': 787.0911513753}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-02-04',
#       'close_approach_date_full': '2024-Feb-04 07:10',
#       'epoch_date_close_approach': 1707030600000,
#       'relative_velocity': {'kilometers_per_second': '14.9596837115',
#        'kilometers_per_hour': '53854.8613613885',
#        'miles_per_hour': '33463.3164942472'},
#       'miss_distance': {'astronomical': '0.049039469',
#        'lunar': '19.076353441',
#        'kilometers': '7336200.10833103',
#        'miles': '4558503.366707014'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3989194?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '3989194',
#     'neo_reference_id': '3989194',
#     'name': '(2020 BP8)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3989194',
#     'absolute_magnitude_h': 25.5,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0211132445,
#       'estimated_diameter_max': 0.0472106499},
#      'meters': {'estimated_diameter_min': 21.113244479,
#       'estimated_diameter_max': 47.2106498806},
#      'miles': {'estimated_diameter_min': 0.0131191578,
#       'estimated_diameter_max': 0.0293353287},
#      'feet': {'estimated_diameter_min': 69.2691770164,
#       'estimated_diameter_max': 154.8905885541}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-04',
#       'close_approach_date_full': '2024-Feb-04 07:38',
#       'epoch_date_close_approach': 1707032280000,
#       'relative_velocity': {'kilometers_per_second': '13.1742398582',
#        'kilometers_per_hour': '47427.2634895895',
#        'miles_per_hour': '29469.4571388508'},
#       'miss_distance': {'astronomical': '0.2751027728',
#        'lunar': '107.0149786192',
#        'kilometers': '41154788.841973936',
#        'miles': '25572399.9784588768'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54051252?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '54051252',
#     'neo_reference_id': '54051252',
#     'name': '(2020 QA2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54051252',
#     'absolute_magnitude_h': 25.4,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.022108281,
#       'estimated_diameter_max': 0.0494356193},
#      'meters': {'estimated_diameter_min': 22.1082810359,
#       'estimated_diameter_max': 49.435619262},
#      'miles': {'estimated_diameter_min': 0.0137374447,
#       'estimated_diameter_max': 0.0307178602},
#      'feet': {'estimated_diameter_min': 72.5337327539,
#       'estimated_diameter_max': 162.1903570994}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-04',
#       'close_approach_date_full': '2024-Feb-04 10:51',
#       'epoch_date_close_approach': 1707043860000,
#       'relative_velocity': {'kilometers_per_second': '11.3187961981',
#        'kilometers_per_hour': '40747.6663131708',
#        'miles_per_hour': '25319.0152155366'},
#       'miss_distance': {'astronomical': '0.4094378732',
#        'lunar': '159.2713326748',
#        'kilometers': '61251033.728050084',
#        'miles': '38059627.5102317992'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54087657?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '54087657',
#     'neo_reference_id': '54087657',
#     'name': '(2020 VV1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54087657',
#     'absolute_magnitude_h': 25.7,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0192555078,
#       'estimated_diameter_max': 0.0430566244},
#      'meters': {'estimated_diameter_min': 19.2555078188,
#       'estimated_diameter_max': 43.0566244241},
#      'miles': {'estimated_diameter_min': 0.0119648141,
#       'estimated_diameter_max': 0.0267541378},
#      'feet': {'estimated_diameter_min': 63.1742402722,
#       'estimated_diameter_max': 141.2618956756}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-04',
#       'close_approach_date_full': '2024-Feb-04 19:26',
#       'epoch_date_close_approach': 1707074760000,
#       'relative_velocity': {'kilometers_per_second': '5.242436076',
#        'kilometers_per_hour': '18872.7698736255',
#        'miles_per_hour': '11726.8052584202'},
#       'miss_distance': {'astronomical': '0.3955248459',
#        'lunar': '153.8591650551',
#        'kilometers': '59169674.478718233',
#        'miles': '36766330.8436602954'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54114205?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '54114205',
#     'neo_reference_id': '54114205',
#     'name': '(2021 CC5)',
# ...
#      'feet': {'estimated_diameter_min': 14.142950711,
#       'estimated_diameter_max': 31.6245991923}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-10',
#       'close_approach_date_full': '2024-Feb-10 13:11',
#       'epoch_date_close_approach': 1707570660000,
#       'relative_velocity': {'kilometers_per_second': '3.1221246719',
#        'kilometers_per_hour': '11239.6488187951',
#        'miles_per_hour': '6983.8806785452'},
#       'miss_distance': {'astronomical': '0.0030742295',
#        'lunar': '1.1958752755',
#        'kilometers': '459898.185091165',
#        'miles': '285767.481001477'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2024-02-11': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2523941?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '2523941',
#     'neo_reference_id': '2523941',
#     'name': '523941 (1998 HK49)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2523941',
#     'absolute_magnitude_h': 22.14,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0992098919,
#       'estimated_diameter_max': 0.2218400624},
#      'meters': {'estimated_diameter_min': 99.2098919421,
#       'estimated_diameter_max': 221.8400624229},
#      'miles': {'estimated_diameter_min': 0.0616461498,
#       'estimated_diameter_max': 0.1378449814},
#      'feet': {'estimated_diameter_min': 325.4917818793,
#       'estimated_diameter_max': 727.8217503997}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-11',
#       'close_approach_date_full': '2024-Feb-11 13:44',
#       'epoch_date_close_approach': 1707659040000,
#       'relative_velocity': {'kilometers_per_second': '5.5860626246',
#        'kilometers_per_hour': '20109.8254484815',
#        'miles_per_hour': '12495.463484919'},
#       'miss_distance': {'astronomical': '0.1412405303',
#        'lunar': '54.9425662867',
#        'kilometers': '21129282.490550461',
#        'miles': '13129127.3339039218'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3447916?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '3447916',
#     'neo_reference_id': '3447916',
#     'name': '(2009 DB1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3447916',
#     'absolute_magnitude_h': 23.01,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0664591797,
#       'estimated_diameter_max': 0.1486072436},
#      'meters': {'estimated_diameter_min': 66.4591797139,
#       'estimated_diameter_max': 148.6072435691},
#      'miles': {'estimated_diameter_min': 0.041295807,
#       'estimated_diameter_max': 0.0923402315},
#      'feet': {'estimated_diameter_min': 218.0419351725,
#       'estimated_diameter_max': 487.5565889914}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-11',
#       'close_approach_date_full': '2024-Feb-11 04:28',
#       'epoch_date_close_approach': 1707625680000,
#       'relative_velocity': {'kilometers_per_second': '15.2708217854',
#        'kilometers_per_hour': '54974.9584273565',
#        'miles_per_hour': '34159.3012517094'},
#       'miss_distance': {'astronomical': '0.0841027804',
#        'lunar': '32.7159815756',
#        'kilometers': '12581596.808917748',
#        'miles': '7817841.7389230024'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3704153?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '3704153',
#     'neo_reference_id': '3704153',
#     'name': '(2015 BE4)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3704153',
#     'absolute_magnitude_h': 23.7,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0483676488,
#       'estimated_diameter_max': 0.1081533507},
#      'meters': {'estimated_diameter_min': 48.3676488219,
#       'estimated_diameter_max': 108.1533506775},
#      'miles': {'estimated_diameter_min': 0.0300542543,
#       'estimated_diameter_max': 0.0672033557},
#      'feet': {'estimated_diameter_min': 158.6865169607,
#       'estimated_diameter_max': 354.8338390368}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-11',
#       'close_approach_date_full': '2024-Feb-11 08:31',
#       'epoch_date_close_approach': 1707640260000,
#       'relative_velocity': {'kilometers_per_second': '25.636236405',
#        'kilometers_per_hour': '92290.4510578729',
#        'miles_per_hour': '57345.6972142655'},
#       'miss_distance': {'astronomical': '0.489044566',
#        'lunar': '190.238336174',
#        'kilometers': '73160025.40867442',
#        'miles': '45459531.802450196'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3736497?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '3736497',
#     'neo_reference_id': '3736497',
#     'name': '(2015 XF261)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3736497',
#     'absolute_magnitude_h': 25.25,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0236894499,
#       'estimated_diameter_max': 0.0529712204},
#      'meters': {'estimated_diameter_min': 23.6894499356,
#       'estimated_diameter_max': 52.9712204056},
#      'miles': {'estimated_diameter_min': 0.0147199372,
#       'estimated_diameter_max': 0.0329147802},
#      'feet': {'estimated_diameter_min': 77.7212949267,
#       'estimated_diameter_max': 173.7900987554}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-11',
#       'close_approach_date_full': '2024-Feb-11 20:58',
#       'epoch_date_close_approach': 1707685080000,
#       'relative_velocity': {'kilometers_per_second': '8.5777210441',
#        'kilometers_per_hour': '30879.7957586973',
#        'miles_per_hour': '19187.5042035083'},
#       'miss_distance': {'astronomical': '0.3128144268',
#        'lunar': '121.6848120252',
#        'kilometers': '46796371.954550916',
#        'miles': '29077917.1716220008'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3787068?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '3787068',
#     'neo_reference_id': '3787068',
#     'name': '(2017 US)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3787068',
#     'absolute_magnitude_h': 26.2,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0152951935,
#       'estimated_diameter_max': 0.0342010925},
#      'meters': {'estimated_diameter_min': 15.2951935344,
#       'estimated_diameter_max': 34.201092472},
#      'miles': {'estimated_diameter_min': 0.0095039897,
#       'estimated_diameter_max': 0.021251567},
#      'feet': {'estimated_diameter_min': 50.1810827555,
#       'estimated_diameter_max': 112.2083122258}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-11',
#       'close_approach_date_full': '2024-Feb-11 16:55',
#       'epoch_date_close_approach': 1707670500000,
#       'relative_velocity': {'kilometers_per_second': '7.8545685031',
#        'kilometers_per_hour': '28276.4466110466',
#        'miles_per_hour': '17569.8842845139'},
#       'miss_distance': {'astronomical': '0.2942976892',
#        'lunar': '114.4818010988',
#        'kilometers': '44026307.450242004',
#        'miles': '27356678.9035234952'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54248949?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '54248949',
#     'neo_reference_id': '54248949',
#     'name': '(2022 EO)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54248949',
#     'absolute_magnitude_h': 29.49,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0033616692,
#       'estimated_diameter_max': 0.0075169209},
#      'meters': {'estimated_diameter_min': 3.3616692116,
#       'estimated_diameter_max': 7.516920875},
#      'miles': {'estimated_diameter_min': 0.0020888438,
#       'estimated_diameter_max': 0.0046707966},
#      'feet': {'estimated_diameter_min': 11.0290988161,
#       'estimated_diameter_max': 24.6618146834}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-11',
#       'close_approach_date_full': '2024-Feb-11 13:14',
#       'epoch_date_close_approach': 1707657240000,
#       'relative_velocity': {'kilometers_per_second': '5.5233332191',
#        'kilometers_per_hour': '19883.9995886394',
#        'miles_per_hour': '12355.1440777299'},
#       'miss_distance': {'astronomical': '0.1867926877',
#        'lunar': '72.6623555153',
#        'kilometers': '27943788.211495199',
#        'miles': '17363464.8400597862'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54357208?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '54357208',
#     'neo_reference_id': '54357208',
#     'name': '(2023 HX6)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54357208',
#     'absolute_magnitude_h': 26.04,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0164647438,
#       'estimated_diameter_max': 0.0368162863},
#      'meters': {'estimated_diameter_min': 16.4647437755,
#       'estimated_diameter_max': 36.8162863142},
#      'miles': {'estimated_diameter_min': 0.0102307143,
#       'estimated_diameter_max': 0.0228765726},
#      'feet': {'estimated_diameter_min': 54.0181899685,
#       'estimated_diameter_max': 120.7883447912}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-11',
#       'close_approach_date_full': '2024-Feb-11 05:53',
#       'epoch_date_close_approach': 1707630780000,
#       'relative_velocity': {'kilometers_per_second': '10.8079497282',
#        'kilometers_per_hour': '38908.6190216586',
#        'miles_per_hour': '24176.3027470967'},
#       'miss_distance': {'astronomical': '0.4271255183',
#        'lunar': '166.1518266187',
#        'kilometers': '63897067.760326021',
#        'miles': '39703796.8167442498'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54423834?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '54423834',
#     'neo_reference_id': '54423834',
#     'name': '(2024 CU)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54423834',
#     'absolute_magnitude_h': 26.33,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0144063837,
#       'estimated_diameter_max': 0.0322136532},
#      'meters': {'estimated_diameter_min': 14.4063836669,
#       'estimated_diameter_max': 32.2136531891},
#      'miles': {'estimated_diameter_min': 0.008951709,
#       'estimated_diameter_max': 0.0200166299},
#      'feet': {'estimated_diameter_min': 47.2650397896,
#       'estimated_diameter_max': 105.6878419288}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-11',
#       'close_approach_date_full': '2024-Feb-11 08:58',
#       'epoch_date_close_approach': 1707641880000,
#       'relative_velocity': {'kilometers_per_second': '7.2489632496',
#        'kilometers_per_hour': '26096.2676986716',
#        'miles_per_hour': '16215.2058930996'},
#       'miss_distance': {'astronomical': '0.0046251832',
#        'lunar': '1.7991962648',
#        'kilometers': '691917.555079784',
#        'miles': '429937.6322536592'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54425074?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '54425074',
#     'neo_reference_id': '54425074',
#     'name': '(2024 CO1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54425074',
#     'absolute_magnitude_h': 20.27,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2347226375,
#       'estimated_diameter_max': 0.5248557734},
#      'meters': {'estimated_diameter_min': 234.7226375313,
#       'estimated_diameter_max': 524.8557733779},
#      'miles': {'estimated_diameter_min': 0.14584984,
#       'estimated_diameter_max': 0.3261301568},
#      'feet': {'estimated_diameter_min': 770.087418118,
#       'estimated_diameter_max': 1721.9678155292}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-11',
#       'close_approach_date_full': '2024-Feb-11 03:40',
#       'epoch_date_close_approach': 1707622800000,
#       'relative_velocity': {'kilometers_per_second': '29.1596360316',
#        'kilometers_per_hour': '104974.6897137416',
#        'miles_per_hour': '65227.1898390746'},
#       'miss_distance': {'astronomical': '0.1106436112',
#        'lunar': '43.0403647568',
#        'kilometers': '16552048.564628144',
#        'miles': '10284966.0578466272'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54426466?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '54426466',
#     'neo_reference_id': '54426466',
#     'name': '(2024 CZ3)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54426466',
#     'absolute_magnitude_h': 24.92,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0275775053,
#       'estimated_diameter_max': 0.0616651765},
#      'meters': {'estimated_diameter_min': 27.5775052924,
#       'estimated_diameter_max': 61.6651764838},
#      'miles': {'estimated_diameter_min': 0.017135862,
#       'estimated_diameter_max': 0.0383169524},
#      'feet': {'estimated_diameter_min': 90.4773824637,
#       'estimated_diameter_max': 202.313577615}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-11',
#       'close_approach_date_full': '2024-Feb-11 07:57',
#       'epoch_date_close_approach': 1707638220000,
#       'relative_velocity': {'kilometers_per_second': '9.2968815331',
#        'kilometers_per_hour': '33468.7735192707',
#        'miles_per_hour': '20796.1943014602'},
#       'miss_distance': {'astronomical': '0.013151454',
#        'lunar': '5.115915606',
#        'kilometers': '1967429.50580298',
#        'miles': '1222504.006641924'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54426473?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#     'id': '54426473',
#     'neo_reference_id': '54426473',
#     'name': '(2024 CH4)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54426473',
#     'absolute_magnitude_h': 27.7,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0076657557,
#       'estimated_diameter_max': 0.0171411509},
#      'meters': {'estimated_diameter_min': 7.6657557353,
#       'estimated_diameter_max': 17.1411509231},
#      'miles': {'estimated_diameter_min': 0.0047632783,
#       'estimated_diameter_max': 0.0106510141},
#      'feet': {'estimated_diameter_min': 25.1501180466,
#       'estimated_diameter_max': 56.2373735944}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-02-11',
#       'close_approach_date_full': '2024-Feb-11 06:10',
#       'epoch_date_close_approach': 1707631800000,
#       'relative_velocity': {'kilometers_per_second': '24.0099275568',
#        'kilometers_per_hour': '86435.7392045088',
#        'miles_per_hour': '53707.8069518238'},
#       'miss_distance': {'astronomical': '0.0007289216',
#        'lunar': '0.2835505024',
#        'kilometers': '109045.118756992',
#        'miles': '67757.4948388096'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}]}}

# %%
all_near_earth_objects = json_data2['near_earth_objects']['2024-02-05']
near_earth_objects
# Out:
# [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2347813?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#   'id': '2347813',
#   'neo_reference_id': '2347813',
#   'name': '347813 (2002 NP1)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2347813',
#   'absolute_magnitude_h': 17.66,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.7808272775,
#     'estimated_diameter_max': 1.7459828712},
#    'meters': {'estimated_diameter_min': 780.8272774914,
#     'estimated_diameter_max': 1745.9828711568},
#    'miles': {'estimated_diameter_min': 0.4851834262,
#     'estimated_diameter_max': 1.0849031226},
#    'feet': {'estimated_diameter_min': 2561.7693650848,
#     'estimated_diameter_max': 5728.2904430061}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-02-05',
#     'close_approach_date_full': '2024-Feb-05 03:32',
#     'epoch_date_close_approach': 1707103920000,
#     'relative_velocity': {'kilometers_per_second': '13.310416415',
#      'kilometers_per_hour': '47917.4990939856',
#      'miles_per_hour': '29774.0704787046'},
#     'miss_distance': {'astronomical': '0.2542580463',
#      'lunar': '98.9063800107',
#      'kilometers': '38036462.156841381',
#      'miles': '23634761.6258018178'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2444627?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#   'id': '2444627',
#   'neo_reference_id': '2444627',
#   'name': '444627 (2006 WU)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2444627',
#   'absolute_magnitude_h': 19.05,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.4116754573,
#     'estimated_diameter_max': 0.9205343072},
#    'meters': {'estimated_diameter_min': 411.6754573069,
#     'estimated_diameter_max': 920.5343072066},
#    'miles': {'estimated_diameter_min': 0.2558031906,
#     'estimated_diameter_max': 0.571993323},
#    'feet': {'estimated_diameter_min': 1350.6413073509,
#     'estimated_diameter_max': 3020.1257764558}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-02-05',
#     'close_approach_date_full': '2024-Feb-05 22:54',
#     'epoch_date_close_approach': 1707173640000,
#     'relative_velocity': {'kilometers_per_second': '1.9982604604',
#      'kilometers_per_hour': '7193.7376574495',
#      'miles_per_hour': '4469.9088238746'},
#     'miss_distance': {'astronomical': '0.4192329873',
#      'lunar': '163.0816320597',
#      'kilometers': '62716361.933817051',
#      'miles': '38970140.2362592638'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2451370?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#   'id': '2451370',
#   'neo_reference_id': '2451370',
#   'name': '451370 (2011 AK5)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2451370',
#   'absolute_magnitude_h': 21.48,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1344481952,
#     'estimated_diameter_max': 0.3006353038},
#    'meters': {'estimated_diameter_min': 134.4481951604,
#     'estimated_diameter_max': 300.6353038309},
#    'miles': {'estimated_diameter_min': 0.0835422095,
#     'estimated_diameter_max': 0.1868060594},
#    'feet': {'estimated_diameter_min': 441.1030166101,
#     'estimated_diameter_max': 986.3363302205}},
#   'is_potentially_hazardous_asteroid': True,
#   'close_approach_data': [{'close_approach_date': '2024-02-05',
#     'close_approach_date_full': '2024-Feb-05 02:23',
#     'epoch_date_close_approach': 1707099780000,
#     'relative_velocity': {'kilometers_per_second': '8.2382303218',
#      'kilometers_per_hour': '29657.6291584367',
#      'miles_per_hour': '18428.0974068075'},
#     'miss_distance': {'astronomical': '0.4318477396',
#      'lunar': '167.9887707044',
#      'kilometers': '64603502.008474652',
#      'miles': '40142754.7037961176'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3440771?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#   'id': '3440771',
#   'neo_reference_id': '3440771',
#   'name': '(2008 WZ94)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3440771',
#   'absolute_magnitude_h': 20.26,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.235806068,
#     'estimated_diameter_max': 0.5272783976},
#    'meters': {'estimated_diameter_min': 235.8060679997,
#     'estimated_diameter_max': 527.2783975542},
#    'miles': {'estimated_diameter_min': 0.1465230523,
#     'estimated_diameter_max': 0.3276355052},
#    'feet': {'estimated_diameter_min': 773.6419801361,
#     'estimated_diameter_max': 1729.9160578319}},
#   'is_potentially_hazardous_asteroid': True,
#   'close_approach_data': [{'close_approach_date': '2024-02-05',
#     'close_approach_date_full': '2024-Feb-05 11:04',
#     'epoch_date_close_approach': 1707131040000,
#     'relative_velocity': {'kilometers_per_second': '16.1492348048',
#      'kilometers_per_hour': '58137.2452971068',
#      'miles_per_hour': '36124.2233347495'},
#     'miss_distance': {'astronomical': '0.4852630626',
#      'lunar': '188.7673313514',
#      'kilometers': '72594320.554636662',
#      'miles': '45108019.1060114556'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3557844?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#   'id': '3557844',
#   'neo_reference_id': '3557844',
#   'name': '(2011 DW)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3557844',
#   'absolute_magnitude_h': 22.7,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0766575574,
#     'estimated_diameter_max': 0.1714115092},
#    'meters': {'estimated_diameter_min': 76.6575573531,
#     'estimated_diameter_max': 171.4115092306},
#    'miles': {'estimated_diameter_min': 0.0476327831,
#     'estimated_diameter_max': 0.1065101409},
#    'feet': {'estimated_diameter_min': 251.5011804664,
#     'estimated_diameter_max': 562.3737359442}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-02-05',
#     'close_approach_date_full': '2024-Feb-05 03:16',
#     'epoch_date_close_approach': 1707102960000,
#     'relative_velocity': {'kilometers_per_second': '14.872591907',
#      'kilometers_per_hour': '53541.3308653544',
#      'miles_per_hour': '33268.5008368643'},
#     'miss_distance': {'astronomical': '0.3844147306',
#      'lunar': '149.5373302034',
#      'kilometers': '57507624.894383822',
#      'miles': '35733581.1211958636'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3616697?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#   'id': '3616697',
#   'neo_reference_id': '3616697',
#   'name': '(2012 VN6)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3616697',
#   'absolute_magnitude_h': 21.36,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1420872067,
#     'estimated_diameter_max': 0.317716653},
#    'meters': {'estimated_diameter_min': 142.0872067277,
#     'estimated_diameter_max': 317.7166529762},
#    'miles': {'estimated_diameter_min': 0.0882888697,
#     'estimated_diameter_max': 0.1974199144},
#    'feet': {'estimated_diameter_min': 466.1653913206,
#     'estimated_diameter_max': 1042.3775037506}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-02-05',
#     'close_approach_date_full': '2024-Feb-05 21:27',
#     'epoch_date_close_approach': 1707168420000,
#     'relative_velocity': {'kilometers_per_second': '19.5250537238',
#      'kilometers_per_hour': '70290.1934055846',
#      'miles_per_hour': '43675.5926747089'},
#     'miss_distance': {'astronomical': '0.3671035055',
#      'lunar': '142.8032636395',
#      'kilometers': '54917902.492333285',
#      'miles': '34124402.239177933'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3719865?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#   'id': '3719865',
#   'neo_reference_id': '3719865',
#   'name': '(2015 KQ57)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3719865',
#   'absolute_magnitude_h': 22.17,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0978486812,
#     'estimated_diameter_max': 0.2187963027},
#    'meters': {'estimated_diameter_min': 97.8486811942,
#     'estimated_diameter_max': 218.7963026589},
#    'miles': {'estimated_diameter_min': 0.0608003329,
#     'estimated_diameter_max': 0.1359536774},
#    'feet': {'estimated_diameter_min': 321.0258672091,
#     'estimated_diameter_max': 717.8356616154}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-02-05',
#     'close_approach_date_full': '2024-Feb-05 16:45',
#     'epoch_date_close_approach': 1707151500000,
#     'relative_velocity': {'kilometers_per_second': '13.7739572245',
#      'kilometers_per_hour': '49586.2460083548',
#      'miles_per_hour': '30810.9649155802'},
#     'miss_distance': {'astronomical': '0.0716046582',
#      'lunar': '27.8542120398',
#      'kilometers': '10711904.348798034',
#      'miles': '6656068.7163355092'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3776069?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#   'id': '3776069',
#   'neo_reference_id': '3776069',
#   'name': '(2017 MZ3)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3776069',
#   'absolute_magnitude_h': 22.43,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0868070458,
#     'estimated_diameter_max': 0.1941064553},
#    'meters': {'estimated_diameter_min': 86.8070457914,
#     'estimated_diameter_max': 194.1064553155},
#    'miles': {'estimated_diameter_min': 0.0539393809,
#     'estimated_diameter_max': 0.1206121222},
#    'feet': {'estimated_diameter_min': 284.8000281143,
#     'estimated_diameter_max': 636.8322228574}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-02-05',
#     'close_approach_date_full': '2024-Feb-05 03:06',
#     'epoch_date_close_approach': 1707102360000,
#     'relative_velocity': {'kilometers_per_second': '25.3080501382',
#      'kilometers_per_hour': '91108.980497664',
#      'miles_per_hour': '56611.5773542291'},
#     'miss_distance': {'astronomical': '0.3684085996',
#      'lunar': '143.3109452444',
#      'kilometers': '55113141.789842852',
#      'miles': '34245718.3131492776'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3802006?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#   'id': '3802006',
#   'neo_reference_id': '3802006',
#   'name': '(2018 FB2)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3802006',
#   'absolute_magnitude_h': 25.6,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0201629919,
#     'estimated_diameter_max': 0.0450858206},
#    'meters': {'estimated_diameter_min': 20.1629919443,
#     'estimated_diameter_max': 45.0858206172},
#    'miles': {'estimated_diameter_min': 0.0125286985,
#     'estimated_diameter_max': 0.0280150214},
#    'feet': {'estimated_diameter_min': 66.1515504905,
#     'estimated_diameter_max': 147.9193637137}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-02-05',
#     'close_approach_date_full': '2024-Feb-05 07:27',
#     'epoch_date_close_approach': 1707118020000,
#     'relative_velocity': {'kilometers_per_second': '5.5296784427',
#      'kilometers_per_hour': '19906.842393732',
#      'miles_per_hour': '12369.3377084831'},
#     'miss_distance': {'astronomical': '0.2897177554',
#      'lunar': '112.7002068506',
#      'kilometers': '43341159.109020998',
#      'miles': '26930947.4657178524'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54341595?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#   'id': '54341595',
#   'neo_reference_id': '54341595',
#   'name': '(2023 CE3)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54341595',
#   'absolute_magnitude_h': 25.2,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0242412481,
#     'estimated_diameter_max': 0.0542050786},
#    'meters': {'estimated_diameter_min': 24.2412481101,
#     'estimated_diameter_max': 54.2050786336},
#    'miles': {'estimated_diameter_min': 0.0150628086,
#     'estimated_diameter_max': 0.0336814639},
#    'feet': {'estimated_diameter_min': 79.5316564495,
#     'estimated_diameter_max': 177.8381901842}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-02-05',
#     'close_approach_date_full': '2024-Feb-05 17:00',
#     'epoch_date_close_approach': 1707152400000,
#     'relative_velocity': {'kilometers_per_second': '15.2642183636',
#      'kilometers_per_hour': '54951.1861089226',
#      'miles_per_hour': '34144.5300575136'},
#     'miss_distance': {'astronomical': '0.0853475503',
#      'lunar': '33.2001970667',
#      'kilometers': '12767811.734597861',
#      'miles': '7933550.3282620418'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54377840?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#   'id': '54377840',
#   'neo_reference_id': '54377840',
#   'name': '(2023 QN2)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54377840',
#   'absolute_magnitude_h': 24.62,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0316632126,
#     'estimated_diameter_max': 0.0708010957},
#    'meters': {'estimated_diameter_min': 31.6632125734,
#     'estimated_diameter_max': 70.8010957001},
#    'miles': {'estimated_diameter_min': 0.0196746021,
#     'estimated_diameter_max': 0.0439937476},
#    'feet': {'estimated_diameter_min': 103.8819343392,
#     'estimated_diameter_max': 232.2870668166}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-02-05',
#     'close_approach_date_full': '2024-Feb-05 01:44',
#     'epoch_date_close_approach': 1707097440000,
#     'relative_velocity': {'kilometers_per_second': '13.7193327839',
#      'kilometers_per_hour': '49389.5980218733',
#      'miles_per_hour': '30688.7755042023'},
#     'miss_distance': {'astronomical': '0.3516341466',
#      'lunar': '136.7856830274',
#      'kilometers': '52603719.350627742',
#      'miles': '32686435.5143251596'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54392655?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#   'id': '54392655',
#   'neo_reference_id': '54392655',
#   'name': '(2023 TZ6)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54392655',
#   'absolute_magnitude_h': 26.43,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0137579896,
#     'estimated_diameter_max': 0.0307638},
#    'meters': {'estimated_diameter_min': 13.7579895932,
#     'estimated_diameter_max': 30.7637999642},
#    'miles': {'estimated_diameter_min': 0.0085488158,
#     'estimated_diameter_max': 0.0191157331},
#    'feet': {'estimated_diameter_min': 45.1377625771,
#     'estimated_diameter_max': 100.9311054747}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-02-05',
#     'close_approach_date_full': '2024-Feb-05 06:07',
#     'epoch_date_close_approach': 1707113220000,
#     'relative_velocity': {'kilometers_per_second': '4.6265154609',
#      'kilometers_per_hour': '16655.455659207',
#      'miles_per_hour': '10349.0524344667'},
#     'miss_distance': {'astronomical': '0.4756383349',
#      'lunar': '185.0233122761',
#      'kilometers': '71154481.791386663',
#      'miles': '44213344.7851274294'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54419609?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#   'id': '54419609',
#   'neo_reference_id': '54419609',
#   'name': '(2024 AJ2)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54419609',
#   'absolute_magnitude_h': 21.12,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1586919792,
#     'estimated_diameter_max': 0.3548460529},
#    'meters': {'estimated_diameter_min': 158.691979174,
#     'estimated_diameter_max': 354.846052917},
#    'miles': {'estimated_diameter_min': 0.0986065938,
#     'estimated_diameter_max': 0.2204910467},
#    'feet': {'estimated_diameter_min': 520.6429929532,
#     'estimated_diameter_max': 1164.1931242522}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-02-05',
#     'close_approach_date_full': '2024-Feb-05 22:01',
#     'epoch_date_close_approach': 1707170460000,
#     'relative_velocity': {'kilometers_per_second': '23.2274071715',
#      'kilometers_per_hour': '83618.6658175271',
#      'miles_per_hour': '51957.3871020073'},
#     'miss_distance': {'astronomical': '0.1909418604',
#      'lunar': '74.2763836956',
#      'kilometers': '28564495.609677348',
#      'miles': '17749154.5326214824'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54423045?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#   'id': '54423045',
#   'neo_reference_id': '54423045',
#   'name': '(2024 BL3)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54423045',
#   'absolute_magnitude_h': 24.48,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0337718597,
#     'estimated_diameter_max': 0.0755161741},
#    'meters': {'estimated_diameter_min': 33.7718597164,
#     'estimated_diameter_max': 75.5161740526},
#    'miles': {'estimated_diameter_min': 0.0209848542,
#     'estimated_diameter_max': 0.0469235606},
#    'feet': {'estimated_diameter_min': 110.8000682321,
#     'estimated_diameter_max': 247.7564844786}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-02-05',
#     'close_approach_date_full': '2024-Feb-05 04:23',
#     'epoch_date_close_approach': 1707106980000,
#     'relative_velocity': {'kilometers_per_second': '15.5068172938',
#      'kilometers_per_hour': '55824.542257743',
#      'miles_per_hour': '34687.1996045404'},
#     'miss_distance': {'astronomical': '0.0508064417',
#      'lunar': '19.7637058213',
#      'kilometers': '7600535.460599179',
#      'miles': '4722753.7382155102'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54423051?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#   'id': '54423051',
#   'neo_reference_id': '54423051',
#   'name': '(2024 BS3)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54423051',
#   'absolute_magnitude_h': 24.35,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0358554334,
#     'estimated_diameter_max': 0.0801751865},
#    'meters': {'estimated_diameter_min': 35.8554334193,
#     'estimated_diameter_max': 80.1751864882},
#    'miles': {'estimated_diameter_min': 0.0222795265,
#     'estimated_diameter_max': 0.0498185358},
#    'feet': {'estimated_diameter_min': 117.6359401793,
#     'estimated_diameter_max': 263.0419588381}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-02-05',
#     'close_approach_date_full': '2024-Feb-05 15:07',
#     'epoch_date_close_approach': 1707145620000,
#     'relative_velocity': {'kilometers_per_second': '17.8529211728',
#      'kilometers_per_hour': '64270.5162219486',
#      'miles_per_hour': '39935.1993713547'},
#     'miss_distance': {'astronomical': '0.1456310099',
#      'lunar': '56.6504628511',
#      'kilometers': '21786088.886988913',
#      'miles': '13537247.9038484794'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54423313?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#   'id': '54423313',
#   'neo_reference_id': '54423313',
#   'name': '(2024 BS4)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54423313',
#   'absolute_magnitude_h': 25.89,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0176422908,
#     'estimated_diameter_max': 0.0394493615},
#    'meters': {'estimated_diameter_min': 17.6422908113,
#     'estimated_diameter_max': 39.4493615328},
#    'miles': {'estimated_diameter_min': 0.0109624079,
#     'estimated_diameter_max': 0.0245126892},
#    'feet': {'estimated_diameter_min': 57.8815333853,
#     'estimated_diameter_max': 129.4270432914}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-02-05',
#     'close_approach_date_full': '2024-Feb-05 08:35',
#     'epoch_date_close_approach': 1707122100000,
#     'relative_velocity': {'kilometers_per_second': '9.4573672168',
#      'kilometers_per_hour': '34046.5219805997',
#      'miles_per_hour': '21155.1847273343'},
#     'miss_distance': {'astronomical': '0.0277228445',
#      'lunar': '10.7841865105',
#      'kilometers': '4147278.487541215',
#      'miles': '2576999.355110167'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54423322?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#   'id': '54423322',
#   'neo_reference_id': '54423322',
#   'name': '(2024 BE5)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54423322',
#   'absolute_magnitude_h': 25.52,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0209196771,
#     'estimated_diameter_max': 0.04677782},
#    'meters': {'estimated_diameter_min': 20.9196770901,
#     'estimated_diameter_max': 46.7778200408},
#    'miles': {'estimated_diameter_min': 0.0129988807,
#     'estimated_diameter_max': 0.0290663808},
#    'feet': {'estimated_diameter_min': 68.6341133843,
#     'estimated_diameter_max': 153.4705431027}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-02-05',
#     'close_approach_date_full': '2024-Feb-05 11:17',
#     'epoch_date_close_approach': 1707131820000,
#     'relative_velocity': {'kilometers_per_second': '9.6038531778',
#      'kilometers_per_hour': '34573.8714401645',
#      'miles_per_hour': '21482.8591734733'},
#     'miss_distance': {'astronomical': '0.0444933645',
#      'lunar': '17.3079187905',
#      'kilometers': '6656112.558333615',
#      'miles': '4135916.558749287'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54423784?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#   'id': '54423784',
#   'neo_reference_id': '54423784',
#   'name': '(2024 CH)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54423784',
#   'absolute_magnitude_h': 25.94,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0172407032,
#     'estimated_diameter_max': 0.0385513844},
#    'meters': {'estimated_diameter_min': 17.2407032437,
#     'estimated_diameter_max': 38.5513844328},
#    'miles': {'estimated_diameter_min': 0.010712873,
#     'estimated_diameter_max': 0.0239547123},
#    'feet': {'estimated_diameter_min': 56.5639888301,
#     'estimated_diameter_max': 126.4809241026}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-02-05',
#     'close_approach_date_full': '2024-Feb-05 14:52',
#     'epoch_date_close_approach': 1707144720000,
#     'relative_velocity': {'kilometers_per_second': '20.7971227826',
#      'kilometers_per_hour': '74869.6420173938',
#      'miles_per_hour': '46521.083952419'},
#     'miss_distance': {'astronomical': '0.0058977997',
#      'lunar': '2.2942440833',
#      'kilometers': '882298.272806639',
#      'miles': '548234.7247400582'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54426076?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#   'id': '54426076',
#   'neo_reference_id': '54426076',
#   'name': '(2024 CN2)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54426076',
#   'absolute_magnitude_h': 25.93,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0173202827,
#     'estimated_diameter_max': 0.0387293295},
#    'meters': {'estimated_diameter_min': 17.3202827141,
#     'estimated_diameter_max': 38.7293295383},
#    'miles': {'estimated_diameter_min': 0.0107623214,
#     'estimated_diameter_max': 0.0240652822},
#    'feet': {'estimated_diameter_min': 56.8250763398,
#     'estimated_diameter_max': 127.0647335225}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-02-05',
#     'close_approach_date_full': '2024-Feb-05 10:06',
#     'epoch_date_close_approach': 1707127560000,
#     'relative_velocity': {'kilometers_per_second': '17.5002946641',
#      'kilometers_per_hour': '63001.0607906866',
#      'miles_per_hour': '39146.4091340797'},
#     'miss_distance': {'astronomical': '0.0308658978',
#      'lunar': '12.0068342442',
#      'kilometers': '4617472.566517686',
#      'miles': '2869164.4079126268'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54426079?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#   'id': '54426079',
#   'neo_reference_id': '54426079',
#   'name': '(2024 CR2)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54426079',
#   'absolute_magnitude_h': 23.88,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0445199816,
#     'estimated_diameter_max': 0.0995497053},
#    'meters': {'estimated_diameter_min': 44.5199816448,
#     'estimated_diameter_max': 99.5497053148},
#    'miles': {'estimated_diameter_min': 0.0276634255,
#     'estimated_diameter_max': 0.0618572999},
#    'feet': {'estimated_diameter_min': 146.0629365795,
#     'estimated_diameter_max': 326.6066551849}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-02-05',
#     'close_approach_date_full': '2024-Feb-05 12:47',
#     'epoch_date_close_approach': 1707137220000,
#     'relative_velocity': {'kilometers_per_second': '11.2207344268',
#      'kilometers_per_hour': '40394.6439364264',
#      'miles_per_hour': '25099.6608392756'},
#     'miss_distance': {'astronomical': '0.0316409438',
#      'lunar': '12.3083271382',
#      'kilometers': '4733417.797269706',
#      'miles': '2941209.4335297028'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54427296?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#   'id': '54427296',
#   'neo_reference_id': '54427296',
#   'name': '(2024 CT8)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54427296',
#   'absolute_magnitude_h': 26.54,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0130784109,
#     'estimated_diameter_max': 0.0292442157},
#    'meters': {'estimated_diameter_min': 13.0784108584,
#     'estimated_diameter_max': 29.2442157171},
#    'miles': {'estimated_diameter_min': 0.0081265452,
#     'estimated_diameter_max': 0.0181715076},
#    'feet': {'estimated_diameter_min': 42.9081734807,
#     'estimated_diameter_max': 95.9455926932}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-02-05',
#     'close_approach_date_full': '2024-Feb-05 08:08',
#     'epoch_date_close_approach': 1707120480000,
#     'relative_velocity': {'kilometers_per_second': '7.553373489',
#      'kilometers_per_hour': '27192.1445605425',
#      'miles_per_hour': '16896.1411576327'},
#     'miss_distance': {'astronomical': '0.0137345572',
#      'lunar': '5.3427427508',
#      'kilometers': '2054660.502513164',
#      'miles': '1276706.8345791032'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54427465?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#   'id': '54427465',
#   'neo_reference_id': '54427465',
#   'name': '(2024 DM)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54427465',
#   'absolute_magnitude_h': 24.98,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0268259417,
#     'estimated_diameter_max': 0.0599846292},
#    'meters': {'estimated_diameter_min': 26.8259417119,
#     'estimated_diameter_max': 59.9846292283},
#    'miles': {'estimated_diameter_min': 0.0166688622,
#     'estimated_diameter_max': 0.037272709},
#    'feet': {'estimated_diameter_min': 88.0116226061,
#     'estimated_diameter_max': 196.7999709574}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-02-05',
#     'close_approach_date_full': '2024-Feb-05 12:54',
#     'epoch_date_close_approach': 1707137640000,
#     'relative_velocity': {'kilometers_per_second': '13.365152469',
#      'kilometers_per_hour': '48114.5488884929',
#      'miles_per_hour': '29896.5095579638'},
#     'miss_distance': {'astronomical': '0.0429297223',
#      'lunar': '16.6996619747',
#      'kilometers': '6422195.015771501',
#      'miles': '3990566.9377526738'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54427939?api_key=eNS888Q2ZwMB5L4XDoFat02MH67UdyT6B13RBXYP'},
#   'id': '54427939',
#   'neo_reference_id': '54427939',
#   'name': '(2024 DT)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54427939',
#   'absolute_magnitude_h': 24.36,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0356906927,
#     'estimated_diameter_max': 0.079806815},
#    'meters': {'estimated_diameter_min': 35.690692667,
#     'estimated_diameter_max': 79.8068149676},
#    'miles': {'estimated_diameter_min': 0.0221771614,
#     'estimated_diameter_max': 0.0495896404},
#    'feet': {'estimated_diameter_min': 117.0954521297,
#     'estimated_diameter_max': 261.8333908182}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-02-05',
#     'close_approach_date_full': '2024-Feb-05 21:49',
#     'epoch_date_close_approach': 1707169740000,
#     'relative_velocity': {'kilometers_per_second': '16.7223711391',
#      'kilometers_per_hour': '60200.5361008842',
#      'miles_per_hour': '37406.27200113'},
#     'miss_distance': {'astronomical': '0.0382685889',
#      'lunar': '14.8864810821',
#      'kilometers': '5724899.387345643',
#      'miles': '3557287.5256821534'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False}]

# %%
near_earth_objects['id']
near_earth_objects['name']
near_earth_objects['estimated_diameter']['kilometers']['estimated_diameter_min']
near_earth_objects['absolute_magnitude_h']
near_earth_objects['close_approach_data'][0]['relative_velocity']['kilometers_per_second']
# Out:
# '1.9982604604'

# %%
df = pd.DataFrame()

for near_earth_objects in all_near_earth_objects:
    #print(f"{pd.Series({'Asteroid ID': near_earth_objects['id'],'Asteroid name':near_earth_objects['name'], 'Minimal estimated diameter in Kilometre':near_earth_objects['estimated_diameter']['kilometers']['estimated_diameter_min'], 'Absolute_magnitude':near_earth_objects['absolute_magnitude_h'], 'Relative velocity(km/s)':near_earth_objects['close_approach_data'][0]['relative_velocity']['kilometers_per_second']})}")
    temp = pd.DataFrame(
        {
        'Asteroid ID': near_earth_objects['id'],
        'Asteroid name':near_earth_objects['name'],
        'Minimal estimated diameter in Kilometre':near_earth_objects['estimated_diameter']['kilometers']['estimated_diameter_min'],
        'Absolute_magnitude':near_earth_objects['absolute_magnitude_h'],
        'Relative velocity(km/s)':near_earth_objects['close_approach_data'][0]['relative_velocity']['kilometers_per_second']
      }
    )
# Combine all DataFrames into a single DataFrame
    df = pd.concat([df, temp])
df

# %%
df = pd.DataFrame([near_earth_objects['id'], near_earth_objects['name'], near_earth_objects['estimated_diameter']['kilometers']['estimated_diameter_min'], near_earth_objects['absolute_magnitude_h'], near_earth_objects['close_approach_data'][0]['relative_velocity']['kilometers_per_second']] for near_earth_objects in all_near_earth_objects )
df.columns = columns=('Asteroid ID', 'Asteroid name','Minimal estimated diameter in Kilometre', 'Absolute_magnitude', 'Relative velocity(km/s)')
df
# Out:
#    Asteroid ID      Asteroid name  Minimal estimated diameter in Kilometre  \
# 0      2347813  347813 (2002 NP1)                                 0.780827
# 1      2444627   444627 (2006 WU)                                 0.411675
# 2      2451370  451370 (2011 AK5)                                 0.134448
# 3      3440771        (2008 WZ94)                                 0.235806
# 4      3557844          (2011 DW)                                 0.076658
# 5      3616697         (2012 VN6)                                 0.142087
# 6      3719865        (2015 KQ57)                                 0.097849
# 7      3776069         (2017 MZ3)                                 0.086807
# 8      3802006         (2018 FB2)                                 0.020163
# 9     54341595         (2023 CE3)                                 0.024241
# 10    54377840         (2023 QN2)                                 0.031663
# 11    54392655         (2023 TZ6)                                 0.013758
# 12    54419609         (2024 AJ2)                                 0.158692
# 13    54423045         (2024 BL3)                                 0.033772
# 14    54423051         (2024 BS3)                                 0.035855
# 15    54423313         (2024 BS4)                                 0.017642
# 16    54423322         (2024 BE5)                                 0.020920
# 17    54423784          (2024 CH)                                 0.017241
# 18    54426076         (2024 CN2)                                 0.017320
# 19    54426079         (2024 CR2)                                 0.044520
# 20    54427296         (2024 CT8)                                 0.013078
# 21    54427465          (2024 DM)                                 0.026826
# 22    54427939          (2024 DT)                                 0.035691
#
#     Absolute_magnitude Relative velocity(km/s)
# 0                17.66            13.310416415
# 1                19.05            1.9982604604
# 2                21.48            8.2382303218
# 3                20.26           16.1492348048
# 4                22.70            14.872591907
# 5                21.36           19.5250537238
# 6                22.17           13.7739572245
# 7                22.43           25.3080501382
# 8                25.60            5.5296784427
# 9                25.20           15.2642183636
# 10               24.62           13.7193327839
# 11               26.43            4.6265154609
# 12               21.12           23.2274071715
# 13               24.48           15.5068172938
# 14               24.35           17.8529211728
# 15               25.89            9.4573672168
# 16               25.52            9.6038531778
# 17               25.94           20.7971227826
# 18               25.93           17.5002946641
# 19               23.88           11.2207344268
# 20               26.54             7.553373489
# 21               24.98            13.365152469
# 22               24.36           16.7223711391
