# %% [markdown]
# <a href="https://colab.research.google.com/github/classical16/gomycode/blob/main/ydata_profiling_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Part 1: Data Exploration with Pandas
# Load the provided dataset into a pandas dataframe
# Use pandas to explore the dataset. For example, you might start by using the head() and info() methods to get an overview of the data.
# Look for missing values in the dataset. You can use the isnull() method to identify missing values.
# Use pandas to calculate some summary statistics for the dataset. For example, you might use the describe() method to get summary statistics for the numerical columns in the dataset.
# Part 2: Data Exploration with ydata-Profiling
# Use ydata-profiling to generate a report of the provided dataset.
# Look for missing values in the dataset. You can use the report generated by ydata-profiling to identify missing values.
# Look for correlations between different columns in the dataset. You can use the report generated by ydata-profiling to identify correlations between different columns.
# Identify any outliers or unusual values in the dataset. You can use the report generated by ydata-profiling to identify any outliers or unusual values.

# %%
# !pip install pandas-profiling

# %%
import pandas as pd

from ydata_profiling import ProfileReport

# %%
df = pd.read_csv('/content/Tunisair_flights_dataset.csv')

# %%
# display first few rows of the dataframe
print("first few rows of the dataset:")
print(df.head())
# Out:
# first few rows of the dataset:
#   Filght_date Flight_ID Departure point Arrival point  \
# 0  2016-01-03  TU 0712              CMN           TUN
# 1  2016-01-13  TU 0757              MXP           TUN
# 2  2016-01-16  TU 0214              TUN           IST
# 3  2016-01-17  TU 0480              DJE           NTE
# 4  2016-01-17  TU 0338              TUN           ALG
#
#   Scheduled_departure_time Scheduled_arrival_time STATUS Aircraft_code  \
# 0      2016-01-03 10:30:00    2016-01-03 12.55.00    ATA     TU 32AIMN
# 1      2016-01-13 15:05:00    2016-01-13 16.55.00    ATA     TU 31BIMO
# 2      2016-01-16 04:10:00    2016-01-16 06.45.00    ATA     TU 32AIMN
# 3      2016-01-17 14:10:00    2016-01-17 17.00.00    ATA     TU 736IOK
# 4      2016-01-17 14:30:00    2016-01-17 15.50.00    ATA     TU 320IMU
#
#    Arrival delay
# 0          260.0
# 1           20.0
# 2            0.0
# 3            0.0
# 4           22.0

# %%
# display a consise summary of the dataframe
print("\nDataFrame information:")
print(df.info())
# Out:
# DataFrame information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24187 entries, 0 to 24186
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Filght_date               24187 non-null  object
#  1   Flight_ID                 24187 non-null  object
#  2   Departure point           24187 non-null  object
#  3   Arrival point             24187 non-null  object
#  4   Scheduled_departure_time  24187 non-null  object
#  5   Scheduled_arrival_time    24187 non-null  object
#  6   STATUS                    24187 non-null  object
#  7   Aircraft_code             24186 non-null  object
#  8   Arrival delay             24186 non-null  float64
# dtypes: float64(1), object(8)
# memory usage: 1.7+ MB
# None

# %%
# check for missing values
missing_values = df.isnull().sum()
print("Missing Values per Column:")
print(missing_values)
# Out:
# Missing Values per Column:
# Filght_date                 0
# Flight_ID                   0
# Departure point             0
# Arrival point               0
# Scheduled_departure_time    0
# Scheduled_arrival_time      0
# STATUS                      0
# Aircraft_code               1
# Arrival delay               1
# dtype: int64

# %%
# display summary statistics for the numerical columns
summary_statistics = df.describe()
print("Summary Statistics for Numerical Columns:")
print(summary_statistics)
# Out:
# Summary Statistics for Numerical Columns:
#        Arrival delay
# count   24186.000000
# mean       38.545894
# std        87.571872
# min         0.000000
# 25%         0.000000
# 50%        14.000000
# 75%        37.000000
# max      2980.000000

# %%
# generate profile report
profile =ProfileReport(df,title='/content/Tunisair_flights_dataset.csv', explorative=True)

# display the report
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.3&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-12-11 14:08:19.597944&quot;&gt;&lt;title&gt;/content/Tunisair_flights_dataset.csv&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# # missing values
# Aircraft_code : 1
# Arrival_delay : 1

# %% [markdown]
# # correlations
# |                 |  Aircraft_code  | Arrival delay  | Status   |
# | ----------------|---------------- |----------------|----------|
# |Aircraft_code    |    1.000        |     0.010      |    0.506 |
# |Arrival delay    |     0.010       |      1.000     |      0.020|
# |Status           |    0.506        |     0.020      |     1.000|

# %% [markdown]
# #outliers
# Arrival-delay :
# Mean: 38
# Median 14
# Maximum: 2980
